# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
data = pd.read_csv('C:\\Users\\Dell\\Downloads\\test.csv')

# %%
display(data.head(10))
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
# 5   6           1464     1          2.9         1   5       1          50
# 6   7           1718     0          2.4         0   1       0          47
# 7   8            833     0          2.4         1   0       0          62
# 8   9           1111     1          2.9         1   9       1          25
# 9  10           1520     0          0.5         0   1       0          25
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# ...

# %%
#scatter plot battery_power against fc
plt.scatter(data['battery_power'], data['fc'])

#adding title to the plot 
plt.title("scatter plot")

#setting the x and y Labels 
plt.xlabel('battery_power')
plt.ylabel('fc')

#adding the legends
plt.show()

# %%
#line chart with year against own
plt.plot(data['battery_power'])
plt.plot(data['fc'])

#adding title to the plot 
plt.title("Line chart")

#setting the x and y labels
plt.xlabel('batery_power')
plt.ylabel('fc')

#adding the legends
plt.show()

# %%
#Bar chart or bar plot
plt.bar(data['battery_power'], data['fc'])

#adding title to the plot
plt.title("bar Chart")

#setting the x and y Lables 
plt.xlabel('battery_power')
plt.ylabel('fc')

#adding the legends
plt.show()

# %%
#Histogram
plt.hist(data['clock_speed'])

plt.title("Histogram")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
